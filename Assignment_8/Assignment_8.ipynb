# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('kc_house_data.csv')

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
sns.lmplot(x='grade',y='price',data=df)

# %% [markdown]
# <h1> Preparing the Data - Test Train <h1>

# %%
x=df[['bedrooms', 'bathrooms','floors', 'waterfront', 'view', 'condition', 'grade']]
y=df['price']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.2,random_state=0)
print(X_train.shape,X_test.shape,Y_train.shape,Y_test.shape)
# Out:
# (17290, 7) (4323, 7) (17290,) (4323,)

# %% [markdown]
# <h1> Training </h1>

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print('y intercept: ',regressor.intercept_)
# Out:
# y intercept:  -1137187.8297856548

# %%
print('slope: ',regressor.coef_)
# Out:
# slope:  [ 15016.50765502  69527.44862244 -33708.71208653 641394.38070657
#   81957.52645222  62248.0037733  169167.75528065]

# %% [markdown]
# <h1> Making the Prediction </h1>

# %%
y_pred = regressor.predict(X_test)

# %%
e = pd.DataFrame({'Actual':Y_test,'Predicted':y_pred})
e
# Out:
#           Actual     Predicted
# 17384   297000.0  2.669285e+05
# 722    1578000.0  1.360430e+06
# 2680    562100.0  2.822004e+05
# 18754   631500.0  5.309980e+05
# 14554   780000.0  9.024483e+05
# 16227   485000.0  3.851812e+05
# 6631    340000.0  4.985198e+05
# 19813   335606.0  5.543489e+05
# 3367    425000.0  7.385332e+05
# 21372   490000.0  1.122451e+06
# 3268    732000.0  7.823443e+05
# 20961   389700.0  3.851812e+05
# 21456   450000.0  4.360963e+05
# 3880    357000.0  2.871144e+05
# 17472   960000.0  8.007812e+05
# 7618    257000.0  2.448081e+05
# 1091    448000.0  3.677993e+05
# 1560    610000.0  5.067843e+05
# 8945    230950.0  1.926625e+05
# 8439    377500.0  3.841262e+05
# 13058   375000.0  4.188899e+05
# 12080   410000.0  5.135363e+05
# 7417    459000.0  4.349614e+05
# 3101    190000.0  1.975766e+05
# 18769   585000.0  6.030742e+05
# 7332    280000.0  1.454310e+05
# 19186   500000.0  3.991427e+05
# 11875   465000.0  4.271545e+05
# 14100   802000.0  1.080141e+06
# ...

# %% [markdown]
# <h1> Evaluating the Algorithm </h1>

# %%
from sklearn import metrics
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error:  157039.67164601048
# Mean Squared Error:  54402403925.50392
# Root Mean Squared Error:  233243.22910966552

# %%
from sklearn.preprocessing import StandardScaler
i = np.array(df[['price','bedrooms', 'bathrooms','floors', 'waterfront', 'view', 'condition', 'grade']])
StandardScaler().fit_transform(i)
# Out:
# array([[-0.86671733, -0.39873715, -1.44746357, ..., -0.30575946,
#         -0.62918687, -0.55883575],
#        [-0.00568792, -0.39873715,  0.1756067 , ..., -0.30575946,
#         -0.62918687, -0.55883575],
#        [-0.98084935, -1.47395936, -1.44746357, ..., -0.30575946,
#         -0.62918687, -1.40958711],
#        ...,
#        [-0.37586519, -1.47395936, -1.77207762, ..., -0.30575946,
#         -0.62918687, -0.55883575],
#        [-0.38158814, -0.39873715,  0.50022075, ..., -0.30575946,
#         -0.62918687,  0.29191561],
#        [-0.58588173, -1.47395936, -1.77207762, ..., -0.30575946,
#         -0.62918687, -0.55883575]])
